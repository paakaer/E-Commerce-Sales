# %%
# read Expense IIGF.csv
# it should contain one column "Recived Amount"
# it's the total amount of money received from sales. (Numeric)
import pandas as pd

expense_iigf_df = pd.read_csv("Expense IIGF.csv")

expense_iigf_df
# Out:
#     index Recived Amount Unnamed: 1  \
# 0       0     Particular     Amount
# 1       1       06-19-22       1000
# 2       2       06-20-22       1500
# 3       3       06-22-22        500
# 4       4       06-23-22       2000
# 5       5            NaN        NaN
# 6       6            NaN        NaN
# 7       7            NaN        NaN
# 8       8            NaN        NaN
# 9       9            NaN        NaN
# 10     10            NaN        NaN
# 11     11            NaN        NaN
# 12     12            NaN        NaN
# 13     13            NaN        NaN
# 14     14            NaN        NaN
# 15     15            NaN        NaN
# 16     16          Total       5000
#
#                                               Expance Unnamed: 3
# 0                                          Particular     Amount
# 1                                           Large Bag        380
# 2   Stationary(Soft Pin, Paper pin for Dupatta, Fe...        170
# ...

# %%
#percentage of missing values in each column
expense_iigf_df.isnull().mean() * 100
# Out:
# index              0.000000
# Recived Amount    64.705882
# Unnamed: 1        64.705882
# Expance           11.764706
# Unnamed: 3         0.000000
# dtype: float64
